# %% [markdown]
# ## Install Required Library to load  the data

# %%
# !pip install roboflow

from roboflow import Roboflow

# %% [markdown]
# ## Load the data

# %%
rf = Roboflow(api_key="lwfvDzXdCDJmMGufTsNP")

project = rf.workspace("mxs9fp").project("project1-rsvx0")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to project1-1 in yolov8:: 100%|██████████| 5226/5226 [00:00<00:00, 5734.29it/s]

# %% [markdown]
# ## Exploratory Data Analysis

# %%
import glob
import random
import cv2
import matplotlib.pyplot as plt

images = glob.glob("project1-1/train/images/*.jpg")
random_image = random.choice(images)

img = cv2.imread(random_image)

plt.imshow(img)
plt.show()

# %%
len(images)
# Out:
# 2268

# %%
import random
import glob

label_paths = glob.glob("project1-1/train/labels/*.txt")
random_label = random.choice(label_paths)

with open(random_label, 'r') as f:
    lines = f.readlines()

print(random_label)
for line in lines:
    print(line.strip())
# Out:
# project1-1/train/labels/Orang-43-_png.rf.5e3e54bf39eed73a411ade7f0f3ca8a7.txt
# 1 0.6105769230769231 0.44471153846153844 0.16826923076923078 0.42788461538461536
# 1 0.5336538461538461 0.13581730769230768 0.12980769230769232 0.27163461538461536

# %%
import glob

image_paths = glob.glob("project1-1/train/images/*.jpg")
image_names = [img.split("/")[-1].split(".")[0] for img in image_paths]

label_paths = glob.glob("project1-1/train/labels/*.txt")
label_names = [lbl.split("/")[-1].split(".")[0] for lbl in label_paths]

no_label_images = set(image_names) - set(label_names)

print(len(no_label_images))
# Out:
# 0

# %%
count_0 = 0
count_1 = 0

for path in label_paths:
    with open(path, 'r') as f:
        lines = f.readlines()
        for line in lines:
            if line.startswith('0'):
                count_0 += 1
            elif line.startswith('1'):
                count_1 += 1

print(" number of classes 0 :" , count_1)
print(" number of classes 1 :" , count_1)
# Out:
#  number of classes 0 : 1563
#  number of classes 1 : 1563
